# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.arima_process import ArmaProcess
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
from tqdm import tqdm #A tqdm progress bar shows you how much time has elapsed and the estimated time remaining for the iterable
import sklearn.metrics as skmetrics #For evaluation metrics
from sklearn.metrics import mean_squared_error
from math import sqrt
from prophet import Prophet

import warnings                               
warnings.filterwarnings('ignore')

# %% [markdown]
# # Feature Engineering

# %%
df=pd.read_csv("train.csv")
df.head()
# Out:
#                     Datetime  ActivePower  AmbientTemperatue  \
# 0  2018-01-01 06:20:00+00:00    26.212347          28.696304
# 1  2018-01-01 06:40:00+00:00    59.632658          29.052567
# 2  2018-01-01 06:50:00+00:00    40.889650          28.984758
# 3  2018-01-01 10:40:00+00:00    34.398111          30.282058
# 4  2018-01-01 12:00:00+00:00    29.797653          29.333519
#
#    BearingShaftTemperature  Blade1PitchAngle  Blade2PitchAngle  \
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
#
#    Blade3PitchAngle  GearboxBearingTemperature  GearboxOilTemperature  \
# 0               NaN                        NaN                    NaN
# 1               NaN                        NaN                    NaN
# 2               NaN                        NaN                    NaN
# 3               NaN                        NaN                    NaN
# 4               NaN                        NaN                    NaN
#
#    GeneratorRPM  GeneratorWinding1Temperature  GeneratorWinding2Temperature  \
# 0           NaN                           NaN                           NaN
# 1           NaN                           NaN                           NaN
# 2           NaN                           NaN                           NaN
# 3           NaN                           NaN                           NaN
# 4           NaN                           NaN                           NaN
#
#    HubTemperature  MainBoxTemperature  NacellePosition  ReactivePower  \
# 0             NaN                 NaN           252.00       3.976499
# 1             NaN                 NaN           255.00      11.091660
# 2             NaN                 NaN           264.75       4.234497
# 3             NaN                 NaN           283.75       5.347792
# 4             NaN                 NaN           274.00       6.022326
#
#    RotorRPM  TurbineStatus  WindDirection  WindSpeed
# 0       NaN            NaN         252.00   3.042750
# 1       NaN            NaN         255.00   3.424814
# 2       NaN            NaN         264.75   3.507172
# 3       NaN            NaN         283.75   3.442212
# 4       NaN            NaN         274.00   3.031363

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])
df.set_index('Datetime', inplace=True)
df
# Out:
#                            ActivePower  AmbientTemperatue  \
# Datetime
# 2018-01-01 06:20:00+00:00    26.212347          28.696304
# 2018-01-01 06:40:00+00:00    59.632658          29.052567
# 2018-01-01 06:50:00+00:00    40.889650          28.984758
# 2018-01-01 10:40:00+00:00    34.398111          30.282058
# 2018-01-01 12:00:00+00:00    29.797653          29.333519
# ...                                ...                ...
# 2020-03-15 23:10:00+00:00   272.852287          23.500851
# 2020-03-15 23:20:00+00:00   295.675931          23.409183
# 2020-03-15 23:30:00+00:00   295.127333          23.336964
# 2020-03-15 23:40:00+00:00   342.942216          23.310323
# 2020-03-15 23:50:00+00:00   374.401860          23.297918
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# Datetime
# 2018-01-01 06:20:00+00:00                      NaN               NaN
# 2018-01-01 06:40:00+00:00                      NaN               NaN
# 2018-01-01 06:50:00+00:00                      NaN               NaN
# 2018-01-01 10:40:00+00:00                      NaN               NaN
# 2018-01-01 12:00:00+00:00                      NaN               NaN
# ...                                            ...               ...
# 2020-03-15 23:10:00+00:00                43.740629         -0.524250
# 2020-03-15 23:20:00+00:00                43.529209         -0.684376
# 2020-03-15 23:30:00+00:00                43.331115         -0.743521
# 2020-03-15 23:40:00+00:00                43.169442         -0.955621
# 2020-03-15 23:50:00+00:00                43.050359         -0.997635
#
#                            Blade2PitchAngle  Blade3PitchAngle  \
# Datetime
# 2018-01-01 06:20:00+00:00               NaN               NaN
# 2018-01-01 06:40:00+00:00               NaN               NaN
# 2018-01-01 06:50:00+00:00               NaN               NaN
# 2018-01-01 10:40:00+00:00               NaN               NaN
# 2018-01-01 12:00:00+00:00               NaN               NaN
# ...                                     ...               ...
# 2020-03-15 23:10:00+00:00         -0.108540         -0.108540
# 2020-03-15 23:20:00+00:00         -0.168882         -0.168882
# 2020-03-15 23:30:00+00:00         -0.292512         -0.292512
# 2020-03-15 23:40:00+00:00         -0.516466         -0.516466
# 2020-03-15 23:50:00+00:00         -0.557849         -0.557849
#
#                            GearboxBearingTemperature  GearboxOilTemperature  \
# Datetime
# 2018-01-01 06:20:00+00:00                        NaN                    NaN
# 2018-01-01 06:40:00+00:00                        NaN                    NaN
# 2018-01-01 06:50:00+00:00                        NaN                    NaN
# 2018-01-01 10:40:00+00:00                        NaN                    NaN
# 2018-01-01 12:00:00+00:00                        NaN                    NaN
# ...                                              ...                    ...
# 2020-03-15 23:10:00+00:00                  63.668076              56.801410
# 2020-03-15 23:20:00+00:00                  63.361840              56.551527
# 2020-03-15 23:30:00+00:00                  63.156279              56.393276
# 2020-03-15 23:40:00+00:00                  63.191997              56.273992
# 2020-03-15 23:50:00+00:00                  63.424068              56.175566
#
#                            GeneratorRPM  GeneratorWinding1Temperature  \
# Datetime
# 2018-01-01 06:20:00+00:00           NaN                           NaN
# 2018-01-01 06:40:00+00:00           NaN                           NaN
# 2018-01-01 06:50:00+00:00           NaN                           NaN
# 2018-01-01 10:40:00+00:00           NaN                           NaN
# 2018-01-01 12:00:00+00:00           NaN                           NaN
# ...                                 ...                           ...
# 2020-03-15 23:10:00+00:00   1029.697556                     64.904780
# 2020-03-15 23:20:00+00:00   1032.996150                     64.109157
# 2020-03-15 23:30:00+00:00   1031.935870                     63.740245
# 2020-03-15 23:40:00+00:00   1047.165900                     63.657965
# 2020-03-15 23:50:00+00:00   1071.970544                     63.752799
#
#                            GeneratorWinding2Temperature  HubTemperature  \
# Datetime
# 2018-01-01 06:20:00+00:00                           NaN             NaN
# 2018-01-01 06:40:00+00:00                           NaN             NaN
# 2018-01-01 06:50:00+00:00                           NaN             NaN
# 2018-01-01 10:40:00+00:00                           NaN             NaN
# 2018-01-01 12:00:00+00:00                           NaN             NaN
# ...                                                 ...             ...
# 2020-03-15 23:10:00+00:00                     64.000634       35.012077
# 2020-03-15 23:20:00+00:00                     63.189782       35.004216
# 2020-03-15 23:30:00+00:00                     62.798514       35.003815
# 2020-03-15 23:40:00+00:00                     62.699627       35.003815
# 2020-03-15 23:50:00+00:00                     62.803517       35.003815
#
#                            MainBoxTemperature  NacellePosition  ReactivePower  \
# Datetime
# 2018-01-01 06:20:00+00:00                 NaN           252.00       3.976499
# 2018-01-01 06:40:00+00:00                 NaN           255.00      11.091660
# 2018-01-01 06:50:00+00:00                 NaN           264.75       4.234497
# 2018-01-01 10:40:00+00:00                 NaN           283.75       5.347792
# 2018-01-01 12:00:00+00:00                 NaN           274.00       6.022326
# ...                                       ...              ...            ...
# 2020-03-15 23:10:00+00:00           35.406250           182.00      54.889963
# 2020-03-15 23:20:00+00:00           35.280933           182.00      60.673948
# 2020-03-15 23:30:00+00:00           35.140925           182.00      59.551241
# 2020-03-15 23:40:00+00:00           35.093750           182.00      69.460091
# 2020-03-15 23:50:00+00:00           35.039062           182.00      75.836758
#
#                            RotorRPM  TurbineStatus  WindDirection  WindSpeed
# Datetime
# 2018-01-01 06:20:00+00:00       NaN            NaN         252.00   3.042750
# 2018-01-01 06:40:00+00:00       NaN            NaN         255.00   3.424814
# 2018-01-01 06:50:00+00:00       NaN            NaN         264.75   3.507172
# 2018-01-01 10:40:00+00:00       NaN            NaN         283.75   3.442212
# 2018-01-01 12:00:00+00:00       NaN            NaN         274.00   3.031363
# ...                             ...            ...            ...        ...
# 2020-03-15 23:10:00+00:00  9.243551            2.0         182.00   5.156629
# 2020-03-15 23:20:00+00:00  9.269149            2.0         182.00   5.257433
# 2020-03-15 23:30:00+00:00  9.252811            2.0         182.00   5.188531
# 2020-03-15 23:40:00+00:00  9.385111            2.0         182.00   5.408458
# 2020-03-15 23:50:00+00:00  9.609502            2.0         182.00   5.637122
#
# [77202 rows x 19 columns]

# %%
# df = df.fillna(df.mean())
# df.isna().sum()

# Fill missing values in all numerical columns with mean
# numeric_columns = df.select_dtypes(include=['number']).columns
# df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())
# df = df.fillna(df.mean())

# %%
df = df.resample('D').mean()
df
# Out:
#                            ActivePower  AmbientTemperatue  \
# Datetime
# 2018-01-01 00:00:00+00:00   366.223561          25.528849
# 2018-01-02 00:00:00+00:00   462.550740          25.357526
# 2018-01-03 00:00:00+00:00   454.417752          24.379363
# 2018-01-04 00:00:00+00:00   369.952190          24.912347
# 2018-01-05 00:00:00+00:00   319.446595          23.535679
# ...                                ...                ...
# 2020-03-11 00:00:00+00:00   466.289248          28.276232
# 2020-03-12 00:00:00+00:00   570.315539          29.094133
# 2020-03-13 00:00:00+00:00   619.637333          30.088163
# 2020-03-14 00:00:00+00:00   800.312824          29.395626
# 2020-03-15 00:00:00+00:00   787.305117          28.176449
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# Datetime
# 2018-01-01 00:00:00+00:00                      NaN               NaN
# 2018-01-02 00:00:00+00:00                      NaN               NaN
# 2018-01-03 00:00:00+00:00                      NaN               NaN
# 2018-01-04 00:00:00+00:00                      NaN               NaN
# 2018-01-05 00:00:00+00:00                      NaN               NaN
# ...                                            ...               ...
# 2020-03-11 00:00:00+00:00                44.059155          0.482881
# 2020-03-12 00:00:00+00:00                44.476550          1.206977
# 2020-03-13 00:00:00+00:00                45.903233          2.168904
# 2020-03-14 00:00:00+00:00                45.924987          3.361067
# 2020-03-15 00:00:00+00:00                45.640587          0.413934
#
#                            Blade2PitchAngle  Blade3PitchAngle  \
# Datetime
# 2018-01-01 00:00:00+00:00               NaN               NaN
# 2018-01-02 00:00:00+00:00               NaN               NaN
# 2018-01-03 00:00:00+00:00               NaN               NaN
# 2018-01-04 00:00:00+00:00               NaN               NaN
# 2018-01-05 00:00:00+00:00               NaN               NaN
# ...                                     ...               ...
# 2020-03-11 00:00:00+00:00          0.934002          0.934002
# 2020-03-12 00:00:00+00:00          1.629283          1.629283
# 2020-03-13 00:00:00+00:00          2.609776          2.609776
# 2020-03-14 00:00:00+00:00          3.771943          3.771943
# 2020-03-15 00:00:00+00:00          0.861263          0.861263
#
#                            GearboxBearingTemperature  GearboxOilTemperature  \
# Datetime
# 2018-01-01 00:00:00+00:00                        NaN                    NaN
# 2018-01-02 00:00:00+00:00                        NaN                    NaN
# 2018-01-03 00:00:00+00:00                        NaN                    NaN
# 2018-01-04 00:00:00+00:00                        NaN                    NaN
# 2018-01-05 00:00:00+00:00                        NaN                    NaN
# ...                                              ...                    ...
# 2020-03-11 00:00:00+00:00                  64.106761              56.921031
# 2020-03-12 00:00:00+00:00                  64.051326              56.194520
# 2020-03-13 00:00:00+00:00                  65.348205              57.663415
# 2020-03-14 00:00:00+00:00                  65.975734              57.703463
# 2020-03-15 00:00:00+00:00                  66.482961              57.333608
#
#                            GeneratorRPM  GeneratorWinding1Temperature  \
# Datetime
# 2018-01-01 00:00:00+00:00           NaN                           NaN
# 2018-01-02 00:00:00+00:00           NaN                           NaN
# 2018-01-03 00:00:00+00:00           NaN                           NaN
# 2018-01-04 00:00:00+00:00           NaN                           NaN
# 2018-01-05 00:00:00+00:00           NaN                           NaN
# ...                                 ...                           ...
# 2020-03-11 00:00:00+00:00   1163.017505                     67.939614
# 2020-03-12 00:00:00+00:00   1217.638162                     70.008635
# 2020-03-13 00:00:00+00:00   1213.959374                     72.745844
# 2020-03-14 00:00:00+00:00   1283.600520                     79.347426
# 2020-03-15 00:00:00+00:00   1323.757190                     77.001938
#
#                            GeneratorWinding2Temperature  HubTemperature  \
# Datetime
# 2018-01-01 00:00:00+00:00                           NaN             NaN
# 2018-01-02 00:00:00+00:00                           NaN             NaN
# 2018-01-03 00:00:00+00:00                           NaN             NaN
# 2018-01-04 00:00:00+00:00                           NaN             NaN
# 2018-01-05 00:00:00+00:00                           NaN             NaN
# ...                                                 ...             ...
# 2020-03-11 00:00:00+00:00                     67.174603       38.635532
# 2020-03-12 00:00:00+00:00                     69.288543       39.978688
# 2020-03-13 00:00:00+00:00                     72.096953       39.562485
# 2020-03-14 00:00:00+00:00                     78.702074       39.610160
# 2020-03-15 00:00:00+00:00                     76.298839       38.031759
#
#                            MainBoxTemperature  NacellePosition  ReactivePower  \
# Datetime
# 2018-01-01 00:00:00+00:00                 NaN       276.727612      74.042120
# 2018-01-02 00:00:00+00:00                 NaN       274.105603      93.555723
# 2018-01-03 00:00:00+00:00                 NaN       286.369130      91.627843
# 2018-01-04 00:00:00+00:00                 NaN       284.445471      74.360621
# 2018-01-05 00:00:00+00:00                 NaN       292.013293      64.366148
# ...                                       ...              ...            ...
# 2020-03-11 00:00:00+00:00           39.955577       183.729298      71.852813
# 2020-03-12 00:00:00+00:00           40.757739       180.773250      84.040654
# 2020-03-13 00:00:00+00:00           41.600482       187.621975      99.693231
# 2020-03-14 00:00:00+00:00           41.525481       177.635623     141.418250
# 2020-03-15 00:00:00+00:00           40.559243       163.307061     121.420402
#
#                             RotorRPM  TurbineStatus  WindDirection  WindSpeed
# Datetime
# 2018-01-01 00:00:00+00:00        NaN            NaN     276.727612   5.263797
# 2018-01-02 00:00:00+00:00        NaN            NaN     274.105603   5.390719
# 2018-01-03 00:00:00+00:00        NaN            NaN     286.369130   5.295225
# 2018-01-04 00:00:00+00:00        NaN            NaN     284.445471   5.094994
# 2018-01-05 00:00:00+00:00        NaN            NaN     292.013293   4.915224
# ...                              ...            ...            ...        ...
# 2020-03-11 00:00:00+00:00  10.420975       2.030612     183.729298   5.385570
# 2020-03-12 00:00:00+00:00  10.931663       2.033333     180.773250   5.693483
# 2020-03-13 00:00:00+00:00  10.884414       2.059259     187.621975   5.765318
# 2020-03-14 00:00:00+00:00  11.506644       2.032787     177.635623   6.217917
# 2020-03-15 00:00:00+00:00  11.870329       2.015748     163.307061   6.458906
#
# [805 rows x 19 columns]

# %%
df = df.fillna(df.mean())

# %%
len(df)
# df=df.dropna()
# Out:
# 805

# %%
missing_values = df['ActivePower'].isnull().sum()
infinite_values = not np.isfinite(df['ActivePower']).all()

print(f'Missing Values: {missing_values}')
print(f'Infinite Values: {infinite_values}')
# Out:
# Missing Values: 0
# Infinite Values: False

# %%
history, test = df[:-15],df[-15:]

# %%
history = history.fillna(history.mean())
test = test.fillna(test.mean())

# %%
len(history), len(test)
# Out:
# (790, 15)

# %%
missing_values = history['ActivePower'].isnull().sum()
infinite_values = not np.isfinite(history['ActivePower']).all()

print(f'Missing Values: {missing_values}')
print(f'Infinite Values: {infinite_values}')
# Out:
# Missing Values: 0
# Infinite Values: False

# %%
# history['ActivePower'].fillna(history['ActivePower'].mean(), inplace=True)
# len(history)

# %%
plt.figure(figsize=(20, 6))
plt.plot(history['ActivePower'])

# %%
#visualize the data
plt.figure(figsize=(30, 10))
plot_acf(history['ActivePower'],lags=100)
plt.show()

plot_pacf(history['ActivePower'],lags=100)
plt.show()

# %%
def adf_test(timeseries):
    #Perform Augmented Dickey-Fuller test:
    print ('Results of Augmented Dickey-Fuller Test:')
    
    dftest = adfuller(timeseries, autolag='AIC')
    
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    
adf_test(history['ActivePower'])
# Out:
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -3.876438
# p-value                          0.002215
# #Lags Used                       7.000000
# Number of Observations Used    782.000000
# Critical Value (1%)             -3.438740
# Critical Value (5%)             -2.865243
# Critical Value (10%)            -2.568742
# dtype: float64

# %% [markdown]
# - Stationary

# %% [markdown]
# # SARIMAX

# %%
def evaluate_models_cv_sarimax(dataset, p_values, d_values, q_values, P_values, D_values, Q_values, m):
    K=5
    result = []
    best_rmse, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                for P in P_values:
                    for D in D_values:
                        for Q in Q_values:
                            trend_order = (p,d,q)
                            seasonal_order = (P,D,Q,m)
                            cfg = [(p,d,q), (P,D,Q,m)]
                            validation_size=15
                            train_size=len(dataset)-validation_size*K
                            rmse=0
                            for k in range(0,5):
                                train, test = dataset[0:train_size+k*validation_size],dataset[train_size+k*validation_size:train_size+(k+1)*validation_size]
                                # exog_train, exog_test = exog[0:train_size+k*validation_size],exog[train_size+k*validation_size:train_size+(k+1)*validation_size]
                                model = sm.tsa.SARIMAX(train, order=trend_order, seasonal_order=seasonal_order) #each step: rolling one step forward to update the train se
                                model_fit = model.fit(disp=False)
                                predictions=model_fit.forecast(validation_size)
                                rmse = rmse+np.sqrt(skmetrics.mean_squared_error(test, predictions))
                            rmse_avg=rmse/3
                            result.append((cfg, rmse_avg))
                            if rmse_avg < best_rmse:
                                best_rmse, best_cfg = rmse_avg, cfg
                                print('SARIMAX%s RMSE=%.3f' % (cfg,rmse_avg))
    print('Best SARIMAX%s RMSE=%.3f' % (best_cfg, best_rmse))

# %%
# order selection
p=[0,1]
d=[1]
q=[0,1,2,5]
P=[1]
D=[0]
Q=[1]
m=12
evaluate_models_cv_sarimax(history['ActivePower'], p,d,q,P,D,Q,m)
# Out:
# SARIMAX[(0, 1, 0), (1, 0, 1, 12)] RMSE=481.173
# SARIMAX[(0, 1, 1), (1, 0, 1, 12)] RMSE=452.304
# SARIMAX[(0, 1, 2), (1, 0, 1, 12)] RMSE=399.793
# SARIMAX[(0, 1, 5), (1, 0, 1, 12)] RMSE=372.016
# SARIMAX[(1, 1, 1), (1, 0, 1, 12)] RMSE=366.485
# Best SARIMAX[(1, 1, 1), (1, 0, 1, 12)] RMSE=366.485

# %% [markdown]
# # PROPHET

# %%
# df = pd.read_csv('DailyDelhiClimateTrain.csv')
# # plt.plot(df)
# df.dtypes
df.reset_index(inplace=True)

df['ds']=pd.to_datetime(df['Datetime'])
df['y']=df['ActivePower']
df=df[['ds','y']]
df['ds'] = df['ds'].dt.strftime('%Y-%m-%d')

# df=df[0:-15]

# %%
df
# Out:
#              ds           y
# 0    2018-01-01  366.223561
# 1    2018-01-02  462.550740
# 2    2018-01-03  454.417752
# 3    2018-01-04  369.952190
# 4    2018-01-05  319.446595
# ..          ...         ...
# 800  2020-03-11  466.289248
# 801  2020-03-12  570.315539
# 802  2020-03-13  619.637333
# 803  2020-03-14  800.312824
# 804  2020-03-15  787.305117
#
# [805 rows x 2 columns]

# %%
#Prophet project
m = Prophet()

#Fit with default settings
m.fit(df)
#Fataframe with forecasting steps
future = m.make_future_dataframe(periods=15)
#Forecast
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# 21:41:19 - cmdstanpy - INFO - Chain [1] start processing
# 21:41:20 - cmdstanpy - INFO - Chain [1] done processing
#             ds        yhat  yhat_lower  yhat_upper
# 815 2020-03-26  566.151252  213.354984  886.515950
# 816 2020-03-27  522.729988  191.830006  833.128463
# 817 2020-03-28  522.845240  195.938749  862.595826
# 818 2020-03-29  502.383029  162.671851  828.981309
# 819 2020-03-30  503.294723  161.239939  851.113260

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(m, initial='789 days', period='15 days', horizon = '15 days')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 21:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 21:41:21 - cmdstanpy - INFO - Chain [1] done processing

# %%
#check performance 

from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv) #by default start with 10% of the horizon
df_p
# Out:
#    horizon            mse        rmse         mae      mape     mdape  \
# 0   1 days   11049.298438  105.115643  105.115643  0.237250  0.237250
# 1   2 days   29280.603107  171.115759  171.115759  0.438728  0.438728
# 2   3 days   46062.923262  214.622746  214.622746  0.629146  0.629146
# 3   4 days  207878.209119  455.936628  455.936628  3.726526  3.726526
# 4   5 days    7651.083618   87.470473   87.470473  0.129223  0.129223
# 5   6 days   46080.385903  214.663425  214.663425  0.621529  0.621529
# 6   7 days    2829.367096   53.191795   53.191795  0.102950  0.102950
# 7   8 days    4522.994894   67.253215   67.253215  0.106845  0.106845
# 8   9 days    9110.841885   95.450730   95.450730  0.141719  0.141719
# 9  10 days      46.153393    6.793629    6.793629  0.011682  0.011682
# 10 11 days   17453.978958  132.113508  132.113508  0.283330  0.283330
# 11 12 days    1551.272910   39.386202   39.386202  0.069060  0.069060
# 12 13 days    1611.876712   40.148184   40.148184  0.064793  0.064793
# 13 14 days   45293.748879  212.823281  212.823281  0.265925  0.265925
# 14 15 days   44212.973676  210.268813  210.268813  0.267074  0.267074
#
#        smape  coverage
# 0   0.212091       1.0
# 1   0.359800       1.0
# 2   0.478593       1.0
# 3   1.301496       0.0
# 4   0.138150       1.0
# 5   0.474173       1.0
# 6   0.097910       1.0
# 7   0.112875       1.0
# 8   0.152527       1.0
# 9   0.011751       1.0
# 10  0.248172       1.0
# 11  0.066755       1.0
# 12  0.066962       1.0
# 13  0.306705       1.0
# 14  0.308235       1.0

# %%
# print(f'Prophet RMSE:', (np.sum(np.sqrt(mean_squared_error(forecast['yhat'][-15:], test['ActivePower'][-15:])) / test['ActivePower'].shape[0])))

# %%
len(forecast['yhat'][-15:])
# Out:
# 15

# %%
forecast['ds'][-15:]
# Out:
# 805   2020-03-16
# 806   2020-03-17
# 807   2020-03-18
# 808   2020-03-19
# 809   2020-03-20
# 810   2020-03-21
# 811   2020-03-22
# 812   2020-03-23
# 813   2020-03-24
# 814   2020-03-25
# 815   2020-03-26
# 816   2020-03-27
# 817   2020-03-28
# 818   2020-03-29
# 819   2020-03-30
# Name: ds, dtype: datetime64[ns]

# %%
# df['date_column'] = pd.to_datetime(df['date_column'], errors='coerce').dt.tz_localize('UTC')

forecast['ds'] = pd.to_datetime(forecast['ds'], errors='coerce').dt.tz_localize('UTC')
df['ds'] = pd.to_datetime(df['ds'], errors='coerce').dt.tz_localize('UTC')

# %%
df['ds']
# Out:
# 0     2018-01-01 00:00:00+00:00
# 1     2018-01-02 00:00:00+00:00
# 2     2018-01-03 00:00:00+00:00
# 3     2018-01-04 00:00:00+00:00
# 4     2018-01-05 00:00:00+00:00
#                  ...
# 800   2020-03-11 00:00:00+00:00
# 801   2020-03-12 00:00:00+00:00
# 802   2020-03-13 00:00:00+00:00
# 803   2020-03-14 00:00:00+00:00
# 804   2020-03-15 00:00:00+00:00
# Name: ds, Length: 805, dtype: datetime64[ns, UTC]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(df['ds'][:-15],df['y'][:-15], label='History Data', marker='o')
plt.plot(df['ds'][-15:],df['y'][-15:], label='Test Data', marker='o')
plt.plot(forecast['ds'][-15:],forecast['yhat'][-15:], label='Forecast Data', marker='o')
plt.xticks(rotation=45) 
# plt.xticks(np.arange(0,len(df), 50))
plt.title('History and Forecast for WindPower')  # Adding a title to the plot
plt.legend()
